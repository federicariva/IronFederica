# %% [markdown]
# ## 1 Strokes data -bring in and explore

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 4E23-324F
#
#  Directory of C:\Users\W10\Documents\formazione\IRONHACK\FirstWeek
#
# 04/13/2022  12:30 PM    <DIR>          .
# 04/13/2022  12:30 PM    <DIR>          ..
# 04/13/2022  10:20 AM    <DIR>          .ipynb_checkpoints
# 04/13/2022  11:23 AM    <DIR>          csv_files
# 04/13/2022  12:30 PM            78,941 Strokes initial.ipynb
# 04/13/2022  09:51 AM         2,635,787 strokes_data.csv
#                2 File(s)      2,714,728 bytes
#                4 Dir(s)  372,085,903,360 bytes free

# %%
import pandas as pd

# %%
#define data frame, read the csv file
strokes = pd.read_csv('strokes_data.csv')

# %%
strokes
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# what is in the data, are there any nulls?
strokes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 4.0+ MB

# %%
#descriptive statistics
strokes.describe()
# Out:
#                  id           age  hypertension  heart_disease  \
# count  43400.000000  43400.000000  43400.000000   43400.000000
# mean   36326.142350     42.217894      0.093571       0.047512
# std    21072.134879     22.519649      0.291235       0.212733
# min        1.000000      0.080000      0.000000       0.000000
# 25%    18038.500000     24.000000      0.000000       0.000000
# 50%    36351.500000     44.000000      0.000000       0.000000
# 75%    54514.250000     60.000000      0.000000       0.000000
# max    72943.000000     82.000000      1.000000       1.000000
#
#        avg_glucose_level           bmi        stroke
# count       43400.000000  41938.000000  43400.000000
# mean          104.482750     28.605038      0.018041
# std            43.111751      7.770020      0.133103
# min            55.000000     10.100000      0.000000
# 25%            77.540000     23.200000      0.000000
# 50%            91.580000     27.700000      0.000000
# ...

# %%
#check the column values
strokes['gender'].value_counts()
# Out:
# Female    25665
# Male      17724
# Other        11
# Name: gender, dtype: int64

# %%
strokes['ever_married'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
strokes.duplicated().value_counts()
# Out:
# False    43400
# dtype: int64

# %%
#identify duplicates
strokes.duplicated().sum()
# Out:
# 0

# %%
strokes.duplicated(subset = 'id').sum()
# Out:
# 0

# %%
print(strokes.duplicated(subset = 'gender').sum())
# Out:
# 43397

# %%
#example for checkind duplicates
df = pd.DataFrame({'one': pd.Series([1., 1, 1]),
                   'two': pd.Series([1., 2., 1])})
df
# Out:
#    one  two
# 0  1.0  1.0
# 1  1.0  2.0
# 2  1.0  1.0

# %%
pwd #check current working directory
# Out:
# 'C:\\Users\\W10\\Documents\\formazione\\IRONHACK\\FirstWeek'

# %% [markdown]
# #python dictionaries
# - () bunch of variables you can use!
# - [] list
# - {} dictionaries: key + values

# %%
#change data type
#change ID from integer to string
#change heart-disease from integer to boolean
strokes["id_str"] = strokes['id'].astype('str')

# %%
strokes['stroke'] = strokes['stroke'].astype('bool')

# %%
strokes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  object
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  bool
#  12  id_str             43400 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(6)
# memory usage: 4.0+ MB

# %%
#transformation from str to boolean in one step
strokes['ever_married'] = strokes['ever_married'].replace({ 'No': False, 'Yes': True})

# %% [markdown]
# create 3 different dataframes from the original datafram
# - df1 = rows 1 to 1000
#     - 1000 index 0 - 1000 #inclusive on the top end, inclusive on bottom end of the range
# - df2 = rows 1001 to 3500
#     - index 1000 - 3499
# - df3 = remaining rows
#     - index 3500

# %%
strokes [0:1000]
# Out:
#         id  gender   age  hypertension  heart_disease  ever_married  \
# 0    30669    Male   3.0             0              0         False
# 1    30468    Male  58.0             1              0          True
# 2    16523  Female   8.0             0              0         False
# 3    56543  Female  70.0             0              0          True
# 4    46136    Male  14.0             0              0         False
# ..     ...     ...   ...           ...            ...           ...
# 995   8727    Male  46.0             0              0          True
# 996   7516    Male  53.0             0              0          True
# 997   6419  Female  79.0             0              0         False
# 998  20425    Male  43.0             0              0          True
# 999  59878  Female  56.0             0              0          True
#
#          work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
strokes [1000:3500]
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 1000  69355    Male   3.0             0              0         False
# 1001   5858    Male  32.0             0              0         False
# 1002  39823  Female  41.0             0              0          True
# 1003  37053    Male  53.0             0              0          True
# 1004   2082    Male  35.0             0              0          True
# ...     ...     ...   ...           ...            ...           ...
# 3495  65894  Female   2.0             0              0         False
# 3496   2291  Female  80.0             1              0          True
# 3497  25630  Female  69.0             0              0          True
# 3498  38575    Male  58.0             1              0          True
# 3499  29326  Female  75.0             0              0          True
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
strokes [3500:]
# Out:
#           id  gender   age  hypertension  heart_disease  ever_married  \
# 3500   59292  Female  60.0             0              0          True
# 3501   52051  Female  75.0             0              0          True
# 3502   64508  Female  10.0             0              0         False
# 3503   36593    Male  38.0             0              0         False
# 3504   39834    Male  28.0             0              0         False
# ...      ...     ...   ...           ...            ...           ...
# 43395  56196  Female  10.0             0              0         False
# 43396   5450  Female  56.0             0              0          True
# 43397  28375  Female  82.0             1              0          True
# 43398  27973    Male  40.0             0              0          True
# 43399  36271  Female  82.0             0              0          True
#
#            work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#iloc #index location
df1 = strokes.iloc[:1000] #df1 = strokes[:1000]
df2 = strokes.iloc[1000:3500] #df2 = strokes[1000:3500]
df3 = strokes.iloc[3500:] #df3 = strokes[3500:]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1000 non-null   int64
#  1   gender             1000 non-null   object
#  2   age                1000 non-null   float64
#  3   hypertension       1000 non-null   int64
#  4   heart_disease      1000 non-null   int64
#  5   ever_married       1000 non-null   bool
#  6   work_type          1000 non-null   object
#  7   Residence_type     1000 non-null   object
#  8   avg_glucose_level  1000 non-null   float64
#  9   bmi                973 non-null    float64
#  10  smoking_status     711 non-null    object
#  11  stroke             1000 non-null   bool
#  12  id_str             1000 non-null   object
# dtypes: bool(2), float64(3), int64(3), object(5)
# memory usage: 88.0+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 1000 to 3499
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2500 non-null   int64
#  1   gender             2500 non-null   object
#  2   age                2500 non-null   float64
#  3   hypertension       2500 non-null   int64
#  4   heart_disease      2500 non-null   int64
#  5   ever_married       2500 non-null   bool
#  6   work_type          2500 non-null   object
#  7   Residence_type     2500 non-null   object
#  8   avg_glucose_level  2500 non-null   float64
#  9   bmi                2391 non-null   float64
#  10  smoking_status     1729 non-null   object
#  11  stroke             2500 non-null   bool
#  12  id_str             2500 non-null   object
# dtypes: bool(2), float64(3), int64(3), object(5)
# memory usage: 219.9+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39900 entries, 3500 to 43399
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 39900 non-null  int64
#  1   gender             39900 non-null  object
#  2   age                39900 non-null  float64
#  3   hypertension       39900 non-null  int64
#  4   heart_disease      39900 non-null  int64
#  5   ever_married       39900 non-null  bool
#  6   work_type          39900 non-null  object
#  7   Residence_type     39900 non-null  object
#  8   avg_glucose_level  39900 non-null  float64
#  9   bmi                38574 non-null  float64
#  10  smoking_status     27668 non-null  object
#  11  stroke             39900 non-null  bool
#  12  id_str             39900 non-null  object
# dtypes: bool(2), float64(3), int64(3), object(5)
# memory usage: 3.4+ MB

# %%
#reset the index on df2 and df3
df2.reset_index(drop=True)
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0     69355    Male   3.0             0              0         False
# 1      5858    Male  32.0             0              0         False
# 2     39823  Female  41.0             0              0          True
# 3     37053    Male  53.0             0              0          True
# 4      2082    Male  35.0             0              0          True
# ...     ...     ...   ...           ...            ...           ...
# 2495  65894  Female   2.0             0              0         False
# 2496   2291  Female  80.0             1              0          True
# 2497  25630  Female  69.0             0              0          True
# 2498  38575    Male  58.0             1              0          True
# 2499  29326  Female  75.0             0              0          True
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df2
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 1000  69355    Male   3.0             0              0         False
# 1001   5858    Male  32.0             0              0         False
# 1002  39823  Female  41.0             0              0          True
# 1003  37053    Male  53.0             0              0          True
# 1004   2082    Male  35.0             0              0          True
# ...     ...     ...   ...           ...            ...           ...
# 3495  65894  Female   2.0             0              0         False
# 3496   2291  Female  80.0             1              0          True
# 3497  25630  Female  69.0             0              0          True
# 3498  38575    Male  58.0             1              0          True
# 3499  29326  Female  75.0             0              0          True
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df2.reset_index(inplace = True, drop=True)

# %%
df3.reset_index(inplace = True, drop=True)

# %%
#concatenate 2 dataframe
#concat - look up in pandas doc for concat
#result = pd.concat ([df1,df2,df3], axis = 0)
df.all = pd.concat ([df1,df2,df3], axis = 0)

# %%
df.all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43400 entries, 0 to 39899
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  bool
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  bool
#  12  id_str             43400 non-null  object
# dtypes: bool(2), float64(3), int64(3), object(5)
# memory usage: 4.1+ MB

# %%
df.all.reset_index(inplace = True, drop=True)

# %%
df.all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43400 entries, 0 to 43399
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 43400 non-null  int64
#  1   gender             43400 non-null  object
#  2   age                43400 non-null  float64
#  3   hypertension       43400 non-null  int64
#  4   heart_disease      43400 non-null  int64
#  5   ever_married       43400 non-null  bool
#  6   work_type          43400 non-null  object
#  7   Residence_type     43400 non-null  object
#  8   avg_glucose_level  43400 non-null  float64
#  9   bmi                41938 non-null  float64
#  10  smoking_status     30108 non-null  object
#  11  stroke             43400 non-null  bool
#  12  id_str             43400 non-null  object
# dtypes: bool(2), float64(3), int64(3), object(5)
# memory usage: 3.7+ MB
