# %%
from sklearn.cluster import KMeans
import pandas as pd

# %%
arrests = pd.read_csv('USArrests.csv')

# %%
arrests.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
arrests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  50 non-null     object
#  1   Murder      50 non-null     float64
#  2   Assault     50 non-null     int64
#  3   UrbanPop    50 non-null     int64
#  4   Rape        50 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.1+ KB

# %%
arrests.describe()
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000

# %%
import matplotlib.pyplot as plt

# %%
arrests.hist(bins = 50, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C4A09ABE0>,
# ...
#       dtype=object)

# %% [markdown]
# # 3. prepare for K means
#  - everything must be numerical
#  - ideally similar scales for each variable

# %%
# move first column to index (because every column must be numerical)
arrests.index = arrests.iloc[:,0]

# %%
arrests = arrests.iloc[:,1:]

# %%
arrests.rename_axis(None, inplace=True) #delete extra header index

# %%
arrests.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
plt.scatter(arrests.iloc[:,0], arrests.iloc[:,3], arrests.iloc[:,2], arrests.iloc[:,1]) # figsize=(20,20)) #x,y,size, color

# %%
plt.scatter(arrests.iloc[:,0], arrests.iloc[:,1], arrests.iloc[:,2], arrests.iloc[:,3]) # figsize=(20,20)) #x,y,size, color

# %%
kmeans = KMeans(n_clusters = 7, random_state = 5)

# %%
cluster = kmeans.fit(arrests)

# %%
cluster.cluster_centers_ #coordinates (4D because we have 4 predictors) of the centers of our n_clusters (in this case 7)
# Out:
# array([[  5.75      , 156.75      ,  74.        ,  19.4       ],
#        [ 12.975     , 271.5       ,  52.5       ,  29.05      ],
#        [  2.95      ,  62.7       ,  53.9       ,  11.51      ],
#        [  5.59      , 112.4       ,  65.6       ,  17.27      ],
#        [ 11.1625    , 251.125     ,  76.375     ,  28.875     ],
#        [ 11.95      , 316.5       ,  68.        ,  26.7       ],
#        [ 11.5       , 195.33333333,  66.16666667,  27.43333333]])

# %%
cluster.labels_  #for each state it tells you to which cluster it belongs
# Out:
# array([4, 1, 5, 6, 4, 6, 3, 4, 5, 6, 2, 3, 4, 3, 2, 3, 3, 4, 2, 5, 0, 4,
#        2, 1, 6, 3, 3, 4, 2, 0, 1, 4, 5, 2, 3, 0, 0, 3, 0, 1, 2, 6, 6, 3,
#        2, 0, 0, 2, 2, 0])

# %%
arrests['cluster'] = cluster.labels_

# %%
arrests['cluster'].value_counts()
# Out:
# 3    10
# 2    10
# 4     8
# 0     8
# 6     6
# 1     4
# 5     4
# Name: cluster, dtype: int64

# %% [markdown]
# # 4. visualization

# %%
import plotly.graph_objs as go

# %%
markersize= arrests['UrbanPop']
markercolour= arrests['cluster']
fig1=go.Scatter3d(x=arrests['Murder'],
                  y=arrests['Rape'],
                  z=arrests['Assault'],
                  marker=dict (size=markersize,
                              color=markercolour,
                              opacity=0.9,
                              colorscale='Blues'),
                  line=dict (width=0.2),
                  mode='markers')
#make layout
mylayout=go.Layout(scene=dict(xaxis=dict(title='Murder'),
                              yaxis=dict(title='Rape'),
                              zaxis=dict(title='Assault')))

# %%
import plotly

# %%
plotly.offline.plot({'data':[fig1],
                    'layout':mylayout},
                   auto_open=True,
                   filename=('5Dplot.html'))
# Out:
# '5Dplot.html'

# %% [markdown]
# # 6 scale before clustering

# %%
#drop cluster
arrests.drop(['cluster'], axis = 1, inplace = True)

# %%
arrests.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(arrests)
# Out:
# StandardScaler()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(arrests)

# %%
scaled_arrests = scaler.transform(arrests)

# %%
scaled_arrests_df = pd.DataFrame(scaled_arrests, columns = ['Murder', 'Assault', 'UrbanPop', 'Rape'])

# %%
scaled_arrests_df.head()
# Out:
#      Murder   Assault  UrbanPop      Rape
# 0  1.255179  0.790787 -0.526195 -0.003451
# 1  0.513019  1.118060 -1.224067  2.509424
# 2  0.072361  1.493817  1.009122  1.053466
# 3  0.234708  0.233212 -1.084492 -0.186794
# 4  0.281093  1.275635  1.776781  2.088814

# %%
scaled_arrests_df.describe()
# Out:
#              Murder       Assault      UrbanPop          Rape
# count  5.000000e+01  5.000000e+01  5.000000e+01  5.000000e+01
# mean  -8.437695e-17  1.298961e-16 -4.263256e-16  8.326673e-16
# std    1.010153e+00  1.010153e+00  1.010153e+00  1.010153e+00
# min   -1.620693e+00 -1.524362e+00 -2.340661e+00 -1.502548e+00
# 25%   -8.611383e-01 -7.486054e-01 -7.704502e-01 -6.640245e-01
# 50%   -1.247758e-01 -1.425453e-01  3.210209e-02 -1.220847e-01
# 75%    8.029251e-01  9.483628e-01  8.521012e-01  5.330962e-01
# max    2.229265e+00  2.015028e+00  1.776781e+00  2.671197e+00

# %%
scaled_arrests_df.hist(bins = 50, figsize = (15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C4D079910>,
# ...
#       dtype=object)

# %% [markdown]
# # 7. reapply clustering

# %%
cluster_scaled = kmeans.fit(scaled_arrests_df)

# %%
cluster.cluster_centers_
# Out:
# array([[-1.18293457, -1.19708982, -1.27640705, -1.16552107],
#        [-0.13215521, -0.21968024, -0.22166938, -0.12502608],
#        [ 0.4608354 ,  0.94533247,  0.6252929 ,  2.28833405],
#        [-0.58476078, -0.57688836,  1.06727821, -0.02861586],
#        [ 0.87540173,  1.22260495,  0.83465436,  0.85799046],
#        [-0.9326486 , -0.82335279,  0.42756263, -0.91477281],
#        [ 1.59644066,  0.97606837, -0.78540457,  0.0489325 ]])

# %%
cluster.labels_
# Out:
# array([6, 2, 4, 1, 2, 2, 5, 1, 4, 6, 3, 0, 4, 1, 0, 1, 1, 6, 0, 4, 3, 4,
#        5, 6, 1, 1, 5, 2, 0, 3, 4, 4, 6, 0, 3, 1, 1, 5, 5, 6, 0, 6, 4, 3,
#        0, 1, 3, 0, 5, 1])

# %%
scaled_arrests_df['cluster'] = cluster.labels_
# Out:
# 1    11
# 4     8
# 0     8
# 6     7
# 5     6
# 3     6
# 2     4
# Name: cluster, dtype: int64

# %%
scaled_arrests_df['cluster'].value_counts()

# %%
scaled_arrests_df
# Out:
#       Murder   Assault  UrbanPop      Rape  cluster
# 0   1.255179  0.790787 -0.526195 -0.003451        6
# 1   0.513019  1.118060 -1.224067  2.509424        2
# 2   0.072361  1.493817  1.009122  1.053466        4
# 3   0.234708  0.233212 -1.084492 -0.186794        1
# 4   0.281093  1.275635  1.776781  2.088814        2
# 5   0.025976  0.402909  0.869548  1.883901        2
# 6  -1.040880 -0.736484  0.799761 -1.092723        5
# 7  -0.437875  0.815030  0.450825 -0.585834        1
# 8   1.765415  1.990786  1.009122  1.150530        4
# 9   2.229265  0.487757 -0.386621  0.492653        6
# 10 -0.577030 -1.512241  1.218484 -0.111300        3
# 11 -1.203228 -0.615272 -0.805344 -0.758392        0
# 12  0.605789  0.948363  1.218484  0.298525        4
# 13 -0.136372 -0.700121 -0.037685 -0.025021        1
# 14 -1.295998 -1.391029 -0.595982 -1.071153        0
# 15 -0.414682 -0.675878  0.032102 -0.348567        1
# 16  0.443441 -0.748605 -0.944918 -0.531910        1
# ...

# %%
markersize= scaled_arrests_df['UrbanPop']
markercolour= scaled_arrests_df['cluster']
fig1=go.Scatter3d(x=scaled_arrests_df['Murder'],
                  y=scaled_arrests_df['Rape'],
                  z=scaled_arrests_df['Assault'],
                  marker=dict (size=markersize,
                              color=markercolour,
                              opacity=0.9,
                              colorscale='Blues'),
                  line=dict (width=0.2),
                  mode='markers')
#make layout
mylayout=go.Layout(scene=dict(xaxis=dict(title='Murder'),
                              yaxis=dict(title='Rape'),
                              zaxis=dict(title='Assault')))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-a7a808298e4d> in <module>
#       1 markersize= scaled_arrests_df['UrbanPop']
#       2 markercolour= scaled_arrests_df['cluster']
# ----> 3 fig1=go.Scatter3d(x=scaled_arrests_df['Murder'],
#       4                   y=scaled_arrests_df['Rape'],
#       5                   z=scaled_arrests_df['Assault'],
#
# ...

# %% [markdown]
# # 9. pick the right number of clusters

# %%
cluster_scaled.inertia_
# Out:
# 40.38326967053932

# %%
K = range(3,15)
inertia = []
for k in K:
    kmeans = KMeans(n_clusters = k, random_state = 5)
    kmeans.fit(scaled_arrests_df)
    inertia.append(kmeans.inertia_)

# %%
inertia
# Out:
# [150.4941542507605,
#  97.75162005084016,
#  73.41467286166886,
#  56.51211210404186,
#  40.38326967053932,
#  35.71451054672962,
#  32.59086420905961,
#  29.389934858995804,
#  26.393974943001048,
#  24.229805702300908,
#  21.802396700490696,
#  19.802709427319698]

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# plot the inertia
plt.figure(figsize = (16,8))
plt.plot(K,inertia,'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1,1.0))
plt.title('elbow method -finding the optimal k by inertia')
# Out:
# Text(0.5, 1.0, 'elbow method -finding the optimal k by inertia')

# %%
from sklearn.metrics import silhouette_score

# %%
K=range(3,9) #what's the range of K that makes sense for your data?
silhouettes = []
for k in K:
    kmeans=KMeans(n_clusters=k, random_state = 5)
    kmeans.fit(scaled_arrests_df)
    silhouettes.append(silhouette_score(scaled_arrests_df,kmeans.predict(scaled_arrests_df)))

# %%
# plot the silhouette/distortion:
plt.figure(figsize =(16,8))
plt.plot(K,silhouettes,'bo-')
plt.xlabel('k')
plt.ylabel('distortion')
plt.xticks(np.arange(min(K),max(K)+1,1.0))
plt.title('finding the optimal k via silhouette')
# Out:
# Text(0.5, 1.0, 'finding the optimal k via silhouette')

# %% [markdown]
# # 10 use the results

# %%
# re run k means with the right number of clusters
# add clusters label into your data frame
# introduce new row (remember to use the same scaler! or go back to raw data)

# %%
fede_state = {'Murder': 2, 'Assault': 10, 'UrbanPop': 200, 'Rape': 4}

# %%
# create a dataframe with our new row
fede_state_df = pd.DataFrame.from_dict([fede_state])

# %%
fede_state_df
# Out:
#    Murder  Assault  UrbanPop  Rape
# 0       2       10       200     4

# %%
fede_state_scaled_df = scaler.transform(fede_state_df)

# %%
fede_state_scaled_df = pd.DataFrame(fede_state_scaled_df, columns = ['Murder', 'Assault', 'UrbanPop', 'Rape'])

# %%
fede_state_scaled_df
# Out:
#      Murder   Assault  UrbanPop      Rape
# 0 -1.342383 -1.948604  9.383581 -1.858449

# %%
kmeans = KMeans(n_clusters = 7, random_state=5)
kmeans.fit(arrests)
# Out:
# KMeans(n_clusters=7, random_state=5)

# %%
kmeans.predict(fede_state_scaled_df)
# Out:
# array([2])

# %%
c_new = 2

# %%
arrests['clusters']=kmeans.labels_
