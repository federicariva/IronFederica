# %% [markdown]
# [Does Computer Vision need Ethics?](https://medium.com/dain-studios/to-what-extent-does-computer-vision-ai-need-ethics-84c0816f565)
#
# My personal thoughts and interpretation of this issue:
#
# In this article, ethical implications of computer vision AI technology are discussed and in particulare of facial and emotion recognition. My personal idea is that, as any other tool invented/created by humans, this technology can for sure be applied for the wrong scopes but given its enormous potential for good scopes, I think it's important to keep going forward. As I said it's the same with a lof of tools invented by humans, such as the trivial knife for example.
#
# Given that, I think it's anyway important to test it widely and to put in place extensive validation programs before distributing it as a commercial tool, in order to avoid things as what happened with google facial recognition

# %%
# %matplotlib inline
from IPython.display import Image
Image('desk.png')

# %% [markdown]
# Category: Home office
# Caption: A very untidy desk with a lot of objects on it.

# %% [markdown]
# [Image Recognition: Dogs vs Cats!](https://thedatafrog.com/en/articles/dogs-vs-cats/)

# %% [markdown]
# 1. Image processing steps by the author:
# - Visual inspection for bad or wrong images and discard wrong or cartoons
# - Turn the images from files into batches of data arrays
# - random sampling some images to check whether they were correctly categorized when imported and transformed
#
#
# 2. pecifically, what did the coder have to do to PROCESS the images in the cat v dogs dataset to enable the image classification method to be accurate:
# - generate new images to increase the dataset?
